# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

import plotly.express as px
import plotly.graph_objs as go
import plotly.figure_factory as ff

import gc

import warnings
warnings.simplefilter("ignore")
plt.style.use("classic")

# %%
data = pd.read_csv('./COVID-19_Case_Surveillance_Public_Use_Data.csv', low_memory=False)
data.head(10)
# Out:
#    Unnamed: 0 Report Date Pos Test Date  Onset Date  \
# 0           0  2020/11/10    2020/11/10         NaN
# 1           1  2020/11/14    2020/11/10  2020/11/10
# 2           2  2020/11/19    2020/11/10  2020/11/09
# 3           3  2020/11/14    2020/11/10         NaN
# 4           4  2020/11/13    2020/11/10  2020/11/10
# 5           5  2020/11/17    2020/11/10  2020/11/08
# 6           6  2020/11/14    2020/11/10         NaN
# 7           7  2020/11/10    2020/11/10         NaN
# 8           8  2020/11/10    2020/11/10         NaN
# 9           9  2020/11/17    2020/11/10         NaN
#
#               Current Status   Sex      Age Group                 Race  \
# 0  Laboratory-confirmed case  Male  10 - 19 Years  Black, Non-Hispanic
# 1  Laboratory-confirmed case  Male  10 - 19 Years  Black, Non-Hispanic
# 2  Laboratory-confirmed case  Male  10 - 19 Years  Black, Non-Hispanic
# 3  Laboratory-confirmed case  Male  10 - 19 Years  Black, Non-Hispanic
# 4  Laboratory-confirmed case  Male  10 - 19 Years  Black, Non-Hispanic
# 5  Laboratory-confirmed case  Male  10 - 19 Years  Black, Non-Hispanic
# 6  Laboratory-confirmed case  Male  10 - 19 Years  Black, Non-Hispanic
# 7  Laboratory-confirmed case  Male  10 - 19 Years  Black, Non-Hispanic
# 8  Laboratory-confirmed case  Male  10 - 19 Years  Black, Non-Hispanic
# 9  Laboratory-confirmed case  Male  10 - 19 Years  Black, Non-Hispanic
#
#   Hospital Y/N ICU Admission Y/N Death Status Underlying Disease
# 0           No           Unknown           No                 No
# 1           No                No           No                 No
# 2           No                No           No                 No
# 3      Missing           Missing           No            Missing
# 4           No                No           No                Yes
# 5      Missing           Missing      Missing            Missing
# 6           No           Missing      Missing            Missing
# 7      Missing           Missing      Missing            Missing
# 8      Unknown           Unknown           No            Unknown
# 9      Missing           Missing      Missing            Missing

# %%
del data['Unnamed: 0']
data.columns = ['Report Date','Pos Test Date', 'Onset Date','Current Status','Sex','Age Group','Race','Hospital Y/N','ICU Admission Y/N','Death Status','Underlying Disease']
data
# Out:
#         Report Date Pos Test Date  Onset Date             Current Status  \
# 0        2020/11/10    2020/11/10         NaN  Laboratory-confirmed case
# 1        2020/11/14    2020/11/10  2020/11/10  Laboratory-confirmed case
# 2        2020/11/19    2020/11/10  2020/11/09  Laboratory-confirmed case
# 3        2020/11/14    2020/11/10         NaN  Laboratory-confirmed case
# 4        2020/11/13    2020/11/10  2020/11/10  Laboratory-confirmed case
# ...             ...           ...         ...                        ...
# 8405074  2020/10/22           NaN         NaN              Probable Case
# 8405075  2020/10/25           NaN         NaN  Laboratory-confirmed case
# 8405076  2020/07/18           NaN         NaN  Laboratory-confirmed case
# 8405077  2020/11/19           NaN         NaN  Laboratory-confirmed case
# 8405078  2020/11/03           NaN         NaN  Laboratory-confirmed case
#
#              Sex      Age Group                 Race Hospital Y/N  \
# 0           Male  10 - 19 Years  Black, Non-Hispanic           No
# 1           Male  10 - 19 Years  Black, Non-Hispanic           No
# 2           Male  10 - 19 Years  Black, Non-Hispanic           No
# 3           Male  10 - 19 Years  Black, Non-Hispanic      Missing
# 4           Male  10 - 19 Years  Black, Non-Hispanic           No
# ...          ...            ...                  ...          ...
# 8405074  Missing  30 - 39 Years              Unknown           No
# 8405075  Missing  30 - 39 Years              Unknown      Missing
# 8405076  Missing  30 - 39 Years              Unknown      Missing
# 8405077  Missing  30 - 39 Years              Unknown      Missing
# 8405078  Missing  30 - 39 Years              Unknown           No
#
#         ICU Admission Y/N Death Status Underlying Disease
# 0                 Unknown           No                 No
# 1                      No           No                 No
# 2                      No           No                 No
# 3                 Missing           No            Missing
# 4                      No           No                Yes
# ...                   ...          ...                ...
# 8405074           Unknown           No            Missing
# 8405075           Missing      Missing            Missing
# 8405076           Missing      Missing            Missing
# 8405077           Missing      Missing            Missing
# 8405078           Unknown           No            Missing
#
# [8405079 rows x 11 columns]

# %% [markdown]
# ## What is the distribution of age groups in this study?

# %% [markdown]
# ### Relative Frequency of Age Groups

# %%
age_freq = data.groupby(['Age Group']).count()['Report Date']
print(age_freq)
print(sum(age_freq))
# Out:
# Age Group
# 0 - 9 Years       299040
# 10 - 19 Years     841450
# 20 - 29 Years    1635264
# 30 - 39 Years    1372623
# 40 - 49 Years    1267350
# 50 - 59 Years    1227493
# 60 - 69 Years     863260
# 70 - 79 Years     483689
# 80+ Years         382869
# Unknown            31952
# Name: Report Date, dtype: int64
# 8404990

# %%
freq_ages = (age_freq / sum(age_freq)) * 100 + '%'
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     142     try:
# --> 143         result = expressions.evaluate(op, left, right)
#     144     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, a, b, use_numexpr)
#     232         if use_numexpr:
# --> 233             return _evaluate(op, op_str, a, b)  # type: ignore
#     234     return _evaluate_standard(op, op_str, a, b)
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     118     if result is None:
# --> 119         result = _evaluate_standard(op, op_str, a, b)
#     120
#
# ~\anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      67     with np.errstate(all="ignore"):
# ---> 68         return op(a, b)
#      69
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> dtype('<U32')
#
# During handling of the above exception, another exception occurred:
#
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-5-a3c0a9bcc0fa> in <module>
# ----> 1 freq_ages = (age_freq / sum(age_freq)) * 100 + '%'
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      63         other = item_from_zerodim(other)
#      64
# ---> 65         return method(self, other)
#      66
#      67     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     341         lvalues = extract_array(left, extract_numpy=True)
#     342         rvalues = extract_array(right, extract_numpy=True)
# --> 343         result = arithmetic_op(lvalues, rvalues, op)
#     344
#     345         return left._construct_result(result, name=res_name)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op)
#     188     else:
#     189         with np.errstate(all="ignore"):
# --> 190             res_values = na_arithmetic_op(lvalues, rvalues, op)
#     191
#     192     return res_values
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, is_cmp)
#     148             #  will handle complex numbers incorrectly, see GH#32047
#     149             raise
# --> 150         result = masked_arith_op(left, right, op)
#     151
#     152     if is_cmp and (is_scalar(result) or result is NotImplemented):
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in masked_arith_op(x, y, op)
#     110         if mask.any():
#     111             with np.errstate(all="ignore"):
# --> 112                 result[mask] = op(xrav[mask], y)
#     113
#     114     result, _ = maybe_upcast_putmask(result, ~mask, np.nan)
#
# UFuncTypeError: ufunc 'add' did not contain a loop with signature matching types (dtype('<U32'), dtype('<U32')) -> dtype('<U32')

# %%
data.describe()

# %%
data.groupby(['Age Group']).count()['Report Date']

# %%
values = data['Age Group'].value_counts()
names = ['20 - 29 Years', '30 - 39 Years', '40 - 49 Years', '50 - 59 Years',
         '60 - 69 Years', '10 - 19 Years', '70 - 79 Years', '80+ Years',
         '0 - 9 Years', 'Unknown']

fig = px.pie(
    names=names,
    values=values,
    title='Age Distribution',
    color_discrete_sequence=px.colors.diverging.RdYlBu,
)
fig.show()

# %%
values = data['Age Group'].value_counts().tolist()
names = ['20 - 29 Years', '30 - 39 Years', '40 - 49 Years', '50 - 59 Years',
         '60 - 69 Years', '10 - 19 Years', '70 - 79 Years', '80+ Years',
         '0 - 9 Years', 'Unknown']

fig = px.bar(
    x=names,
    y=values,
    title='Age Distribution',
    labels={
        'x':'Age Ranges',
        'y':'Number of Patients'
    },
    color=values
)
fig.show()

# %% [markdown]
# ## How many confirmed cases are there?

# %%
data.groupby(['Current Status']).count()['Report Date']

# %%
values = data['Current Status'].value_counts().tolist()
names = ['Confirmed','Probable']

fig = px.pie(
    names=names,
    values=values,
    title='Confirmed Cases vs Probable Cases',
    color_discrete_sequence=px.colors.sequential.Rainbow,
)
fig.show()

# %%
confirmed = 0.941
probable = 0.0589

confirmed_cases = round(confirmed * 8405079)
confirmed_cases

# %% [markdown]
# ## How many individuals died because of Covid-19?

# %%
data.groupby(['Death Status']).count()['Report Date']

# %%
values = data['Death Status'].value_counts().tolist()
names = ['Missing','No','Unknown','Yes']

fig = px.pie(
    names=names,
    values=values,
    title='Death Distribution',
    color_discrete_sequence=px.colors.diverging.Spectral,
)
fig.show()

# %%
data.describe()
